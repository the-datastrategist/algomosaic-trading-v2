# %% [markdown]
# # extract: binance_minute_i00
#
# ETL pipeline for asset prices (OHLCV), standard indicators and engineered features. Loads output data to [BigQuery](https://console.cloud.google.com/bigquery?project=algomosaic-nyc&p=algomosaic-nyc&page=project).

# %%
import datetime as dt
from src.extract import ticker_extract
from algom import configs

# %%
#### Add list of tickers
tickers = [
    'ADA-USDT',
    'BCH-USDT',
    'BNB-USDT',
    'BTC-USDT',
    'ETH-USDT',
    'EOS-USDT',
    'LTC-USDT',
    'LINK-USDT',
    'NEO-USDT',
    'OMG-USDT',
    'TRX-USDT',
    'XRP-USDT',
    'XLM-USDT',
    'ZRX-USDT',
]

# %%
interval='minute'
iteration='i00'
runtime = dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
partition = dt.datetime.now().strftime('%Y%m%d')


for ticker in tickers:
    print("RUNNING: {}".format(ticker))
    model = ticker_extract.run_extract_process(
        ticker=ticker,
        start_date=None,
        end_date=None,
        project_id=configs.GOOGLE_PROJECT_ID,
        destination_table='train_features.features_{ticker}_{interval}_{iteration}_{partition}',
        table_params={
            'ticker': ticker,
            'interval': interval,
            'iteration': iteration,
            'partition': partition
        },
        interval=interval,
        exchange='binance',
        data_library='src.extract.cryptocompare_ticker_data',
        features_library='src.features.algom_trading_v001.get_features_minute_i00',
        to_bq=True,
        if_exists='replace'
    )
# Out:
# RUNNING: ADA-USDT
# RUNNING: algom-trading:train_features.features_{ticker}_{interval}_{iteration}_{partition} is being extracted and transformed.
# RUNNING: Extracting data using src.extract.cryptocompare_ticker_data.
# Extracting 1 of 22: ADA-USDT up to 2021-01-18 13:22:14
# Extracting 2 of 22: ADA-USDT up to 2021-01-17 04:02:14
# Extracting 3 of 22: ADA-USDT up to 2021-01-15 18:42:14
# Extracting 4 of 22: ADA-USDT up to 2021-01-14 09:22:14
# Extracting 5 of 22: ADA-USDT up to 2021-01-13 00:02:14
# Extracting 6 of 22: ADA-USDT up to 2021-01-11 14:42:14
# Extracting 7 of 22: ADA-USDT up to 2021-01-10 05:22:14
# Extracting 8 of 22: ADA-USDT up to 2021-01-08 20:02:14
# Extracting 9 of 22: ADA-USDT up to 2021-01-07 10:42:14
# Extracting 10 of 22: ADA-USDT up to 2021-01-06 01:22:14
# Extracting 11 of 22: ADA-USDT up to 2021-01-04 16:02:14
# Extracting 12 of 22: ADA-USDT up to 2021-01-03 06:42:14
# Extracting 13 of 22: ADA-USDT up to 2021-01-01 21:22:14
# Extracting 14 of 22: ADA-USDT up to 2020-12-31 12:02:14
# Extracting 15 of 22: ADA-USDT up to 2020-12-30 02:42:14
# Extracting 16 of 22: ADA-USDT up to 2020-12-28 17:22:14
# Extracting 17 of 22: ADA-USDT up to 2020-12-27 08:02:14
# Extracting 18 of 22: ADA-USDT up to 2020-12-25 22:42:14
# Extracting 19 of 22: ADA-USDT up to 2020-12-24 13:22:14
# Extracting 20 of 22: ADA-USDT up to 2020-12-23 04:02:14
# Extracting 21 of 22: ADA-USDT up to 2020-12-21 18:42:14
# Extracting 22 of 22: ADA-USDT up to 2020-12-20 09:22:14
# RUNNING: Applying feature engineering using src.features.algom_trading_v001.get_features_minute_i00.
# RUNNING: Cleaning final dataset.
# SUCCESS: Loaded DataFrame.
# RUNNING: loading features into BigQuery.
# 1it [00:03,  3.97s/it]

# %%
# list(model.data.df)
model.data.df.tail()
# Out:
#    ticker_time_sec   close    high     low    open  volume_base    volume  \
# 4     1.610870e+09  0.5239  0.5262  0.5220  0.5262     59174.20  31016.04
# 3     1.610870e+09  0.5250  0.5268  0.5236  0.5239     18195.01   9561.08
# 2     1.610870e+09  0.5244  0.5258  0.5244  0.5250      2202.45   1156.71
# 1     1.610870e+09  0.5243  0.5244  0.5243  0.5244       509.66    267.21
# 0     1.610870e+09  0.5237  0.5243  0.5237  0.5243         0.00      0.00
#
#   conversionType conversionSymbol partition_date  ...  MIN_24  MIN_48 MIN_150  \
# 4   force_direct                      2021-01-17  ...  0.5194  0.5194  0.5194
# 3   force_direct                      2021-01-17  ...  0.5194  0.5194  0.5194
# 2   force_direct                      2021-01-17  ...  0.5194  0.5194  0.5194
# 1   force_direct                      2021-01-17  ...  0.5194  0.5194  0.5194
# 0   force_direct                      2021-01-17  ...  0.5194  0.5194  0.5194
#
#   MIN_200   MAX_6  MAX_12  MAX_24  MAX_48  MAX_150  MAX_200
# 4  0.5194  0.5262  0.5262  0.5322  0.5393   0.5468   0.5645
# 3  0.5194  0.5262  0.5262  0.5283  0.5393   0.5468   0.5632
# 2  0.5194  0.5262  0.5262  0.5281  0.5393   0.5468   0.5632
# 1  0.5194  0.5262  0.5262  0.5276  0.5393   0.5468   0.5632
# 0  0.5194  0.5262  0.5262  0.5276  0.5393   0.5468   0.5632
#
# [5 rows x 135 columns]

# %%
print(model.data.df.ticker_time.max())
print(model.data.df.ticker_time.min())
print(model.data.df.interval.min())
# Out:
# 2021-01-17 07:57:00
# 2021-01-10 07:58:00
# minute
