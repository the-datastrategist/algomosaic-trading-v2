# %% [markdown]
# ##### algom/playbooks
#
# # etl
#
# ETL pipeline for asset prices (OHLCV), standard indicators and engineered features. Loads output data to [BigQuery](https://console.cloud.google.com/bigquery?project=algomosaic-nyc&p=algomosaic-nyc&page=project).

# %% [markdown]
# #### Steps
#
# 1. Initialize ETL process
# 2. Specify data and feature libraries (optional)
# 3. Run ETL process and without loading to BigQuery
# 4. Run ETL process and load to BigQuery
#
# <br>

# %%
import sys
sys.path.append('/home/jovyan/algom-trading/src')

# %% [markdown]
# <br><br>
#
# ### BTC-USD -- hour -- i01 -- 2016

# %%
from etl import ticker_etl
model = ticker_etl.run_etl_process(
    ticker='BTC-USD',
    start_date='2016-01-01',
    end_date='2017-01-01',
    project='algomosaic-nyc',
    destination_table='algom_dev_features.features_{ticker}_{interval}_{iteration}_2016',
    table_params={
        'ticker': 'BTC-USD',
        'interval': 'hour',
        'iteration': 'i01'
    },
    interval='hour',
    exchange='CCCAGG',
    data_library='etl.cryptocompare_ticker_data',
    features_library='etl.algom_trading_v001.get_features_hour_i01',
    to_bq=True
)
model.data.df.tail()
# Out:
# RUNNING: algomosaic-nyc:algom_dev_features.features_{ticker}_{interval}_{iteration}_2016 is being extracted and transformed.
# RUNNING: Extracting data using etl.cryptocompare_ticker_data.
# Extracting 1 of 5: BTC-USD up to 2017-01-01 00:00:00
# Extracting 2 of 5: BTC-USD up to 2016-10-09 16:00:00
# Extracting 3 of 5: BTC-USD up to 2016-07-18 08:00:00
# Extracting 4 of 5: BTC-USD up to 2016-04-26 00:00:00
# Extracting 5 of 5: BTC-USD up to 2016-02-02 16:00:00
# RUNNING: Applying feature engineering using etl.algom_trading_v001.get_features_hour_i01.
# RUNNING: loading features into BigQuery.
# RUNNING: loading algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2016 into BigQuery.
# 1it [01:10, 70.55s/it]
# SUCCESS: algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2016 has been loaded to BigQuery. Runtime: 0:01:32.676635.
#       partition_date                   etl_time         ticker_time   ticker  \
# 9996      2020-04-03 2020-04-03 11:43:26.117956 2015-11-11 12:00:00  BTC-USD
# 9997      2020-04-03 2020-04-03 11:43:26.117956 2015-11-11 11:00:00  BTC-USD
# 9998      2020-04-03 2020-04-03 11:43:26.117956 2015-11-11 10:00:00  BTC-USD
# 9999      2020-04-03 2020-04-03 11:43:26.117956 2015-11-11 09:00:00  BTC-USD
# 10000     2020-04-03 2020-04-03 11:43:26.117956 2015-11-11 08:00:00  BTC-USD
#
#       exchange interval  ticker_time_sec   close    high     low  ...  \
# 9996    CCCAGG     hour       1447243200  318.61  321.15  313.75  ...
# 9997    CCCAGG     hour       1447239600  314.77  323.37  313.89  ...
# 9998    CCCAGG     hour       1447236000  322.44  326.23  319.54  ...
# 9999    CCCAGG     hour       1447232400  321.70  324.94  313.08  ...
# 10000   CCCAGG     hour       1447228800  313.07  313.85  308.62  ...
#
#        RATIO_close_5_close_10  RATIO_close_5_close_15  RATIO_close_5_close_30  \
# 9996                 1.030643                0.979103                0.940534
# 9997                 0.992751                0.965622                0.950285
# 9998                 0.996856                0.977387                0.953604
# 9999                 1.022320                1.018922                0.970087
# 10000                1.045538                1.061037                0.995866
#
#        RATIO_close_10_close_15  RATIO_close_10_close_30  \
# 9996                  0.949992                 0.912570
# 9997                  0.972673                 0.957224
# 9998                  0.980469                 0.956611
# 9999                  0.996676                 0.948908
# 10000                 1.014824                 0.952491
#
#        RATIO_close_10_close_60  RATIO_close_10_close_90  \
# 9996                  0.897031                 0.907195
# 9997                  0.929643                 0.932072
# 9998                  0.937368                 0.939006
# 9999                  0.934378                 0.934602
# 10000                 0.932272                 0.922854
#
#        RATIO_close_15_close_30  RATIO_close_15_close_60  \
# 9996                  0.960608                 0.944251
# 9997                  0.984117                 0.955761
# 9998                  0.975667                 0.956041
# 9999                  0.952072                 0.937494
# 10000                 0.938578                 0.918655
#
#        RATIO_close_15_close_90
# 9996                  0.954950
# 9997                  0.958258
# 9998                  0.957711
# 9999                  0.937719
# 10000                 0.909374
#
# [5 rows x 313 columns]

# %% [markdown]
# <br><br>
#
# ### BTC-USD -- hour -- i01 -- 2017

# %%
model = ticker_etl.run_etl_process(
    ticker='BTC-USD',
    start_date='2017-01-01',
    end_date='2018-01-01',
    project='algomosaic-nyc',
    destination_table='algom_dev_features.features_{ticker}_{interval}_{iteration}_2017',
    table_params={
        'ticker': 'BTC-USD',
        'interval': 'hour',
        'iteration': 'i01'
    },
    interval='hour',
    exchange='CCCAGG',
    data_library='etl.cryptocompare_ticker_data',
    features_library='etl.algom_trading_v001.get_features_hour_i01',
    to_bq=True
)
model.data.df.tail()
# Out:
# RUNNING: algomosaic-nyc:algom_dev_features.features_{ticker}_{interval}_{iteration}_2017 is being extracted and transformed.
# RUNNING: Extracting data using etl.cryptocompare_ticker_data.
# Extracting 1 of 5: BTC-USD up to 2018-01-01 00:00:00
# Extracting 2 of 5: BTC-USD up to 2017-10-09 16:00:00
# Extracting 3 of 5: BTC-USD up to 2017-07-18 08:00:00
# Extracting 4 of 5: BTC-USD up to 2017-04-26 00:00:00
# Extracting 5 of 5: BTC-USD up to 2017-02-01 16:00:00
# RUNNING: Applying feature engineering using etl.algom_trading_v001.get_features_hour_i01.
# RUNNING: loading features into BigQuery.
# RUNNING: loading algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2017 into BigQuery.
# 1it [01:11, 71.57s/it]
# SUCCESS: algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2017 has been loaded to BigQuery. Runtime: 0:01:32.943694.
#       partition_date                   etl_time         ticker_time   ticker  \
# 9996      2020-04-03 2020-04-03 11:44:58.593547 2016-11-10 12:00:00  BTC-USD
# 9997      2020-04-03 2020-04-03 11:44:58.593547 2016-11-10 11:00:00  BTC-USD
# 9998      2020-04-03 2020-04-03 11:44:58.593547 2016-11-10 10:00:00  BTC-USD
# 9999      2020-04-03 2020-04-03 11:44:58.593547 2016-11-10 09:00:00  BTC-USD
# 10000     2020-04-03 2020-04-03 11:44:58.593547 2016-11-10 08:00:00  BTC-USD
#
#       exchange interval  ticker_time_sec   close    high     low  ...  \
# 9996    CCCAGG     hour       1478779200  716.39  718.20  715.44  ...
# 9997    CCCAGG     hour       1478775600  717.54  717.92  715.46  ...
# 9998    CCCAGG     hour       1478772000  716.58  718.33  714.83  ...
# 9999    CCCAGG     hour       1478768400  714.37  716.37  711.53  ...
# 10000   CCCAGG     hour       1478764800  715.64  717.01  712.51  ...
#
#        RATIO_close_5_close_10  RATIO_close_5_close_15  RATIO_close_5_close_30  \
# 9996                 1.004457                0.999678                0.996847
# 9997                 1.007148                0.996269                0.996227
# 9998                 1.005277                0.998086                0.998770
# 9999                 1.002940                0.995184                0.995115
# 10000                1.007051                0.999665                0.997129
#
#        RATIO_close_10_close_15  RATIO_close_10_close_30  \
# 9996                  0.995242                 0.992423
# 9997                  0.989198                 0.989156
# 9998                  0.992846                 0.993527
# 9999                  0.992266                 0.992197
# 10000                 0.992665                 0.990147
#
#        RATIO_close_10_close_60  RATIO_close_10_close_90  \
# 9996                  1.008536                 1.012441
# 9997                  1.006012                 1.006827
# 9998                  1.005832                 1.010236
# 9999                  1.009043                 1.011066
# 10000                 1.009176                 1.013957
#
#        RATIO_close_15_close_30  RATIO_close_15_close_60  \
# 9996                  0.997167                 1.013358
# 9997                  0.999958                 1.016998
# 9998                  1.000685                 1.013079
# 9999                  0.999930                 1.016907
# 10000                 0.997464                 1.016633
#
#        RATIO_close_15_close_90
# 9996                  1.017281
# 9997                  1.017822
# 9998                  1.017515
# 9999                  1.018946
# 10000                 1.021450
#
# [5 rows x 313 columns]

# %% [markdown]
# <br><br>
#
# ### BTC-USD -- hour -- i01 -- 2018

# %%
model = ticker_etl.run_etl_process(
    ticker='BTC-USD',
    start_date='2018-01-01',
    end_date='2019-01-01',
    project='algomosaic-nyc',
    destination_table='algom_dev_features.features_{ticker}_{interval}_{iteration}_2018',
    table_params={
        'ticker': 'BTC-USD',
        'interval': 'hour',
        'iteration': 'i01'
    },
    interval='hour',
    exchange='CCCAGG',
    data_library='etl.cryptocompare_ticker_data',
    features_library='etl.algom_trading_v001.get_features_hour_i01',
    to_bq=True
)
model.data.df.tail()
# Out:
# RUNNING: algomosaic-nyc:algom_dev_features.features_{ticker}_{interval}_{iteration}_2018 is being extracted and transformed.
# RUNNING: Extracting data using etl.cryptocompare_ticker_data.
# Extracting 1 of 5: BTC-USD up to 2019-01-01 00:00:00
# Extracting 2 of 5: BTC-USD up to 2018-10-09 16:00:00
# Extracting 3 of 5: BTC-USD up to 2018-07-18 08:00:00
# Extracting 4 of 5: BTC-USD up to 2018-04-26 00:00:00
# Extracting 5 of 5: BTC-USD up to 2018-02-01 16:00:00
# RUNNING: Applying feature engineering using etl.algom_trading_v001.get_features_hour_i01.
# RUNNING: loading features into BigQuery.
# RUNNING: loading algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2018 into BigQuery.
# 1it [01:05, 65.74s/it]
# SUCCESS: algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2018 has been loaded to BigQuery. Runtime: 0:01:29.534978.
#       partition_date                   etl_time         ticker_time   ticker  \
# 9996      2020-04-03 2020-04-03 11:46:31.224056 2017-11-10 12:00:00  BTC-USD
# 9997      2020-04-03 2020-04-03 11:46:31.224056 2017-11-10 11:00:00  BTC-USD
# 9998      2020-04-03 2020-04-03 11:46:31.224056 2017-11-10 10:00:00  BTC-USD
# 9999      2020-04-03 2020-04-03 11:46:31.224056 2017-11-10 09:00:00  BTC-USD
# 10000     2020-04-03 2020-04-03 11:46:31.224056 2017-11-10 08:00:00  BTC-USD
#
#       exchange interval  ticker_time_sec    close     high      low  ...  \
# 9996    CCCAGG     hour       1510315200  6727.32  6898.64  6702.58  ...
# 9997    CCCAGG     hour       1510311600  6868.73  7097.86  6837.07  ...
# 9998    CCCAGG     hour       1510308000  7095.18  7122.40  7081.79  ...
# 9999    CCCAGG     hour       1510304400  7090.04  7207.66  7086.68  ...
# 10000   CCCAGG     hour       1510300800  7174.54  7188.11  7148.34  ...
#
#        RATIO_close_5_close_10  RATIO_close_5_close_15  RATIO_close_5_close_30  \
# 9996                 1.010285                1.000646                1.084689
# 9997                 1.045033                1.014081                1.079500
# 9998                 1.062378                1.001752                1.067053
# 9999                 1.025277                1.003594                1.064583
# 10000                1.053368                1.039898                1.065486
#
#        RATIO_close_10_close_15  RATIO_close_10_close_30  \
# 9996                  0.990459                 1.073646
# 9997                  0.970381                 1.032981
# 9998                  0.942934                 1.004400
# 9999                  0.978852                 1.038337
# 10000                 0.987213                 1.011504
#
#        RATIO_close_10_close_60  RATIO_close_10_close_90  \
# 9996                  1.109516                 1.016275
# 9997                  1.118238                 1.001379
# 9998                  1.128116                 0.969821
# 9999                  1.113558                 0.986394
# 10000                 1.088344                 0.974958
#
#        RATIO_close_15_close_30  RATIO_close_15_close_60  \
# 9996                  1.083989                 1.120204
# 9997                  1.064511                 1.152370
# 9998                  1.065186                 1.196390
# 9999                  1.060770                 1.137616
# 10000                 1.024606                 1.102442
#
#        RATIO_close_15_close_90
# 9996                  1.026065
# 9997                  1.031943
# 9998                  1.028514
# 9999                  1.007705
# 10000                 0.987586
#
# [5 rows x 313 columns]

# %% [markdown]
# <br><br>
#
# ### BTC-USD -- hour -- i01 -- 2019

# %%
model = ticker_etl.run_etl_process(
    ticker='BTC-USD',
    start_date='2019-01-01',
    end_date='2020-01-01',
    project='algomosaic-nyc',
    destination_table='algom_dev_features.features_{ticker}_{interval}_{iteration}_2019',
    table_params={
        'ticker': 'BTC-USD',
        'interval': 'hour',
        'iteration': 'i01'
    },
    interval='hour',
    exchange='CCCAGG',
    data_library='etl.cryptocompare_ticker_data',
    features_library='etl.algom_trading_v001.get_features_hour_i01',
    to_bq=True
)
model.data.df.tail()
# Out:
# RUNNING: algomosaic-nyc:algom_dev_features.features_{ticker}_{interval}_{iteration}_2019 is being extracted and transformed.
# RUNNING: Extracting data using etl.cryptocompare_ticker_data.
# Extracting 1 of 5: BTC-USD up to 2020-01-01 00:00:00
# Extracting 2 of 5: BTC-USD up to 2019-10-09 16:00:00
# Extracting 3 of 5: BTC-USD up to 2019-07-18 08:00:00
# Extracting 4 of 5: BTC-USD up to 2019-04-26 00:00:00
# Extracting 5 of 5: BTC-USD up to 2019-02-01 16:00:00
# RUNNING: Applying feature engineering using etl.algom_trading_v001.get_features_hour_i01.
# RUNNING: loading features into BigQuery.
# RUNNING: loading algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2019 into BigQuery.
# 1it [01:05, 65.96s/it]
# SUCCESS: algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2019 has been loaded to BigQuery. Runtime: 0:01:28.024841.

# %% [markdown]
# <br><br>
#
# ### BTC-USD -- hour -- i01 -- 2020 to date

# %%
model = ticker_etl.run_etl_process(
    ticker='BTC-USD',
    start_date='2020-01-01',
    #end_date='2020-01-01',
    project='algomosaic-nyc',
    destination_table='algom_dev_features.features_{ticker}_{interval}_{iteration}_2020',
    table_params={
        'ticker': 'BTC-USD',
        'interval': 'hour',
        'iteration': 'i01'
    },
    interval='hour',
    exchange='CCCAGG',
    data_library='etl.cryptocompare_ticker_data',
    features_library='etl.algom_trading_v001.get_features_hour_i01',
    to_bq=True
)
model.data.df.tail()
# Out:
# RUNNING: algomosaic-nyc:algom_dev_features.features_{ticker}_{interval}_{iteration}_2020 is being extracted and transformed.
# RUNNING: Extracting data using etl.cryptocompare_ticker_data.
# Extracting 1 of 2: BTC-USD up to 2020-04-03 00:00:00
# Extracting 2 of 2: BTC-USD up to 2020-01-10 16:00:00
# RUNNING: Applying feature engineering using etl.algom_trading_v001.get_features_hour_i01.
# RUNNING: loading features into BigQuery.
# RUNNING: loading algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2020 into BigQuery.
# 1it [00:35, 35.90s/it]
# SUCCESS: algomosaic-nyc:algom_dev_features.features_BTC_USD_hour_i01_2020 has been loaded to BigQuery. Runtime: 0:00:46.981848.
#      partition_date                   etl_time         ticker_time   ticker  \
# 3996     2020-04-03 2020-04-03 11:56:57.221704 2019-10-19 12:00:00  BTC-USD
# 3997     2020-04-03 2020-04-03 11:56:57.221704 2019-10-19 11:00:00  BTC-USD
# 3998     2020-04-03 2020-04-03 11:56:57.221704 2019-10-19 10:00:00  BTC-USD
# 3999     2020-04-03 2020-04-03 11:56:57.221704 2019-10-19 09:00:00  BTC-USD
# 4000     2020-04-03 2020-04-03 11:56:57.221704 2019-10-19 08:00:00  BTC-USD
#
#      exchange interval  ticker_time_sec    close     high      low  ...  \
# 3996   CCCAGG     hour       1571486400  8084.22  8108.69  7919.05  ...
# 3997   CCCAGG     hour       1571482800  7976.43  7994.06  7963.54  ...
# 3998   CCCAGG     hour       1571479200  7980.60  8002.40  7955.92  ...
# 3999   CCCAGG     hour       1571475600  7983.07  8005.95  7977.24  ...
# 4000   CCCAGG     hour       1571472000  7994.46  8014.38  7963.07  ...
#
#       RATIO_close_5_close_10  RATIO_close_5_close_15  RATIO_close_5_close_30  \
# 3996                1.008811                1.014321                0.983981
# 3997                1.004015                1.008164                0.977344
# 3998                1.008352                1.014773                0.990185
# 3999                1.002562                1.010382                0.994755
# 4000                1.006651                1.011563                1.001643
#
#       RATIO_close_10_close_15  RATIO_close_10_close_30  \
# 3996                 1.005462                 0.975386
# 3997                 1.004133                 0.973436
# 3998                 1.006368                 0.981984
# 3999                 1.007800                 0.992213
# 4000                 1.004880                 0.995025
#
#       RATIO_close_10_close_60  RATIO_close_10_close_90  \
# 3996                 0.971674                 0.997140
# 3997                 0.969625                 1.000497
# 3998                 0.970704                 0.997861
# 3999                 0.975388                 1.006224
# 4000                 0.974760                 0.995046
#
#       RATIO_close_15_close_30  RATIO_close_15_close_60  \
# 3996                 0.970088                 0.966396
# 3997                 0.969429                 0.965634
# 3998                 0.975769                 0.964561
# 3999                 0.984533                 0.967839
# 4000                 0.990193                 0.970027
#
#       RATIO_close_15_close_90
# 3996                 0.991723
# 3997                 0.996379
# 3998                 0.991546
# 3999                 0.998436
# 4000                 0.990214
#
# [5 rows x 313 columns]

# %%
list(model.data.df)
# Out:
# ['partition_date',
#  'etl_time',
#  'ticker_time',
#  'ticker',
#  'exchange',
#  'interval',
#  'ticker_time_sec',
#  'close',
#  'high',
#  'low',
#  'open',
#  'volume_base',
#  'volume',
#  'ROR_n1',
#  'ROR_n3',
#  'ROR_n5',
#  'ROR_n10',
#  'ROR_n15',
#  'ROR_n20',
#  'ROR_n25',
#  'ROR_n30',
#  'AROR_1',
#  'AROR_2',
#  'AROR_3',
#  'AROR_4',
#  'AROR_5',
#  'AROR_6',
#  'AROR_7',
#  'AROR_8',
#  'AROR_9',
#  'AROR_10',
#  'AROR_15',
#  'AROR_20',
#  'AROR_25',
#  'AROR_30',
#  'AROR_40',
#  'AROR_50',
#  'AROR_60',
#  'AROR_70',
#  'AROR_80',
#  'AROR_90',
#  'AROR_100',
#  'AROR_110',
#  'AROR_120',
#  'AROR_130',
#  'AROR_140',
#  'AROR_150',
#  'AROR_160',
#  'AROR_170',
#  'AROR_180',
#  'AROR_190',
#  'AROR_200',
#  'AROR_210',
#  'AROR_220',
#  'AROR_230',
#  'AROR_240',
#  'AROR_250',
#  'AROR_300',
#  'EMA_3',
#  'EMA_4',
#  'EMA_5',
#  'EMA_10',
#  'EMA_15',
#  'EMA_20',
#  'EMA_25',
#  'EMA_30',
#  'EMA_50',
#  'EMA_75',
#  'EMA_100',
#  'EMA_150',
#  'EMA_175',
#  'EMA_200',
#  'EMA_volume_3',
#  'EMA_volume_5',
#  'EMA_volume_10',
#  'EMA_volume_15',
#  'EMA_volume_20',
#  'EMA_volume_25',
#  'EMA_volume_50',
#  'EMA_volume_100',
#  'EMA_volume_200',
#  'ATR_',
#  'BollingerB_5',
#  'Bollinger_pct_b_5',
#  'BollingerB_10',
#  'Bollinger_pct_b_10',
#  'BollingerB_15',
#  'Bollinger_pct_b_15',
#  'BollingerB_20',
#  'Bollinger_pct_b_20',
#  'BollingerB_25',
#  'Bollinger_pct_b_25',
#  'BollingerB_30',
#  'Bollinger_pct_b_30',
#  'BollingerB_40',
#  'Bollinger_pct_b_40',
#  'BollingerB_50',
#  'Bollinger_pct_b_50',
#  'BollingerB_60',
#  'Bollinger_pct_b_60',
#  'BollingerB_70',
#  'Bollinger_pct_b_70',
#  'BollingerB_80',
#  'Bollinger_pct_b_80',
#  'BollingerB_90',
#  'Bollinger_pct_b_90',
#  'BollingerB_100',
#  'Bollinger_pct_b_100',
#  'BollingerB_110',
#  'Bollinger_pct_b_110',
#  'BollingerB_120',
#  'Bollinger_pct_b_120',
#  'BollingerB_130',
#  'Bollinger_pct_b_130',
#  'BollingerB_140',
#  'Bollinger_pct_b_140',
#  'BollingerB_150',
#  'Bollinger_pct_b_150',
#  'BollingerB_160',
#  'Bollinger_pct_b_160',
#  'BollingerB_170',
#  'Bollinger_pct_b_170',
#  'BollingerB_180',
#  'Bollinger_pct_b_180',
#  'BollingerB_190',
#  'Bollinger_pct_b_190',
#  'BollingerB_200',
#  'Bollinger_pct_b_200',
#  'MACD_10_20',
#  'MACDsign_10_20',
#  'MACDdiff_10_20',
#  'MACD_12_26',
#  'MACDsign_12_26',
#  'MACDdiff_12_26',
#  'MACD_9_12',
#  'MACDsign_9_12',
#  'MACDdiff_9_12',
#  'MACD_26_200',
#  'MACDsign_26_200',
#  'MACDdiff_26_200',
#  'MACD_20_200',
#  'MACDsign_20_200',
#  'MACDdiff_20_200',
#  'SO_EMA_nK10_nS1',
#  'SO_EMA_nD1_nS1',
#  'SO_EMA_nK20_nS1',
#  'SO_EMA_nD5_nS1',
#  'SO_EMA_nK30_nS1',
#  'SO_EMA_nD10_nS1',
#  'SO_EMA_nK40_nS1',
#  'SO_EMA_nK50_nS1',
#  'SO_EMA_nK60_nS1',
#  'SO_EMA_nK70_nS1',
#  'SO_EMA_nK80_nS1',
#  'SO_EMA_nK90_nS1',
#  'SO_EMA_nK100_nS1',
#  'SO_EMA_nK10_nS5',
#  'SO_EMA_nD1_nS5',
#  'SO_EMA_nK20_nS5',
#  'SO_EMA_nD5_nS5',
#  'SO_EMA_nK30_nS5',
#  'SO_EMA_nD10_nS5',
#  'SO_EMA_nK40_nS5',
#  'SO_EMA_nK50_nS5',
#  'SO_EMA_nK60_nS5',
#  'SO_EMA_nK70_nS5',
#  'SO_EMA_nK80_nS5',
#  'SO_EMA_nK90_nS5',
#  'SO_EMA_nK100_nS5',
#  'RSI_',
#  'Mass_Index_9_25',
#  'SO_pct_k',
#  'Acc_Dist_ROC_5',
#  'Acc_Dist_ROC_10',
#  'Acc_Dist_ROC_50',
#  'Vortex_5',
#  'Vortex_10',
#  'Vortex_20',
#  'Vortex_50',
#  'MIN_3',
#  'MIN_4',
#  'MIN_5',
#  'MIN_6',
#  'MIN_7',
#  'MIN_8',
#  'MIN_9',
#  'MIN_10',
#  'MIN_20',
#  'MIN_30',
#  'MIN_40',
#  'MIN_50',
#  'MIN_100',
#  'MIN_200',
#  'MAX_3',
#  'MAX_4',
#  'MAX_5',
#  'MAX_6',
#  'MAX_7',
#  'MAX_8',
#  'MAX_9',
#  'MAX_10',
#  'MAX_20',
#  'MAX_30',
#  'MAX_40',
#  'MAX_50',
#  'MAX_100',
#  'MAX_200',
#  'RATIO_LOG_MIN_5_MIN_10',
#  'RATIO_LOG_MIN_5_MIN_20',
#  'RATIO_LOG_MIN_5_MIN_30',
#  'RATIO_LOG_MIN_5_MIN_40',
#  'RATIO_LOG_MIN_5_MIN_50',
#  'RATIO_LOG_MIN_10_MIN_10',
#  'RATIO_LOG_MIN_10_MIN_20',
#  'RATIO_LOG_MIN_10_MIN_30',
#  'RATIO_LOG_MIN_10_MIN_40',
#  'RATIO_LOG_MIN_10_MIN_50',
#  'RATIO_LOG_MIN_20_MIN_50',
#  'RATIO_LOG_MIN_20_MIN_100',
#  'RATIO_LOG_MIN_20_MIN_200',
#  'RATIO_LOG_MIN_50_MIN_100',
#  'RATIO_LOG_MIN_50_MIN_200',
#  'RATIO_LOG_MAX_5_MAX_10',
#  'RATIO_LOG_MAX_5_MAX_20',
#  'RATIO_LOG_MAX_5_MAX_30',
#  'RATIO_LOG_MAX_5_MAX_40',
#  'RATIO_LOG_MAX_5_MAX_50',
#  'RATIO_LOG_MAX_10_MAX_10',
#  'RATIO_LOG_MAX_10_MAX_20',
#  'RATIO_LOG_MAX_10_MAX_30',
#  'RATIO_LOG_MAX_10_MAX_40',
#  'RATIO_LOG_MAX_10_MAX_50',
#  'RATIO_LOG_MAX_20_MAX_50',
#  'RATIO_LOG_MAX_20_MAX_100',
#  'RATIO_LOG_MAX_20_MAX_200',
#  'RATIO_LOG_MAX_50_MAX_100',
#  'RATIO_LOG_MAX_50_MAX_200',
#  'RATIO_LOG_MIN_5_MAX_5',
#  'RATIO_LOG_MIN_10_MAX_10',
#  'RATIO_LOG_MIN_20_MAX_20',
#  'RATIO_LOG_MIN_50_MAX_50',
#  'RATIO_LOG_MIN_100_MAX_100',
#  'DIFF_AROR_1_AROR_3',
#  'DIFF_AROR_1_AROR_5',
#  'DIFF_AROR_1_AROR_10',
#  'DIFF_AROR_1_AROR_15',
#  'DIFF_AROR_1_AROR_20',
#  'DIFF_AROR_1_AROR_25',
#  'DIFF_AROR_1_AROR_50',
#  'DIFF_AROR_3_AROR_5',
#  'DIFF_AROR_3_AROR_10',
#  'DIFF_AROR_3_AROR_15',
#  'DIFF_AROR_3_AROR_20',
#  'DIFF_AROR_3_AROR_25',
#  'DIFF_AROR_3_AROR_50',
#  'DIFF_AROR_5_AROR_10',
#  'DIFF_AROR_5_AROR_15',
#  'DIFF_AROR_5_AROR_20',
#  'DIFF_AROR_5_AROR_25',
#  'DIFF_AROR_5_AROR_50',
#  'DIFF_AROR_5_AROR_100',
#  'DIFF_AROR_10_AROR_20',
#  'DIFF_AROR_10_AROR_25',
#  'DIFF_AROR_10_AROR_50',
#  'DIFF_AROR_10_AROR_100',
#  'DIFF_AROR_10_AROR_150',
#  'DIFF_AROR_10_AROR_200',
#  'RATIO_LOG_EMA_3_EMA_5',
#  'RATIO_LOG_EMA_3_EMA_10',
#  'RATIO_LOG_EMA_3_EMA_15',
#  'RATIO_LOG_EMA_5_EMA_10',
#  'RATIO_LOG_EMA_5_EMA_15',
#  'RATIO_LOG_EMA_5_EMA_20',
#  'RATIO_LOG_EMA_5_EMA_25',
#  'RATIO_LOG_EMA_5_EMA_50',
#  'RATIO_LOG_EMA_5_EMA_100',
#  'RATIO_LOG_EMA_5_EMA_200',
#  'RATIO_LOG_EMA_10_EMA_15',
#  'RATIO_LOG_EMA_10_EMA_25',
#  'RATIO_LOG_EMA_10_EMA_50',
#  'RATIO_LOG_EMA_10_EMA_100',
#  'RATIO_LOG_EMA_10_EMA_200',
#  'RATIO_LOG_EMA_25_EMA_50',
#  'RATIO_LOG_EMA_25_EMA_100',
#  'RATIO_LOG_EMA_25_EMA_200',
#  'RATIO_LOG_EMA_50_EMA_100',
#  'RATIO_LOG_EMA_50_EMA_200',
#  'RATIO_LOG_volume_EMA_volume_3',
#  'RATIO_LOG_volume_EMA_volume_5',
#  'RATIO_LOG_volume_EMA_volume_10',
#  'RATIO_LOG_EMA_volume_3_EMA_volume_10',
#  'RATIO_LOG_EMA_volume_5_EMA_volume_10',
#  'RATIO_LOG_EMA_volume_3_EMA_volume_15',
#  'RATIO_LOG_EMA_volume_5_EMA_volume_15',
#  'RATIO_LOG_EMA_volume_10_EMA_volume_15',
#  'RATIO_close_close_3',
#  'RATIO_close_close_5',
#  'RATIO_close_close_10',
#  'RATIO_close_close_15',
#  'RATIO_close_close_30',
#  'RATIO_close_3_close_5',
#  'RATIO_close_3_close_10',
#  'RATIO_close_3_close_15',
#  'RATIO_close_5_close_10',
#  'RATIO_close_5_close_15',
#  'RATIO_close_5_close_30',
#  'RATIO_close_10_close_15',
#  'RATIO_close_10_close_30',
#  'RATIO_close_10_close_60',
#  'RATIO_close_10_close_90',
#  'RATIO_close_15_close_30',
#  'RATIO_close_15_close_60',
#  'RATIO_close_15_close_90']
