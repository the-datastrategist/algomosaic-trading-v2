# %% [markdown]
# # Model training
#
# #### BTC-USDT for ROR_n24 with price action features
#
#
# <br>
#
# #### Performance by Model ID
#
# ```
# model_id:
#     - n_estimates = 500
#     - max_depth = 10
#         - Mean Absolute Error:	 0.03134
#         - Mean Absolute Outcome:	 0.03069
#         - Mean Absolute Percent Error:	 1.02143
#         - Error Variance:	 0.00206
#         - R-Squared:		 0.02457
#
# ```
#
#
# ```
# model_id:
#     - n_estimates = 500
#     - max_depth=20
# ```
#
#
#
# <br>
#
# #### Resources
# + [BigQuery](https://console.cloud.google.com/bigquery?folder=&organizationId=&project=algomosaic-nyc)
# + [Storage](https://console.cloud.google.com/storage/browser/algom-trading/models/?project=algomosaic-nyc)

# %% [markdown]
# <br>
#
# #### Requirements

# %%
import numpy as np
from algom import configs
from algom.utils.data_object import dataObject
from algom.model_regression import modelRegression
from algom.model_plots import modelPlots

# %% [markdown]
# <br>
#
# ### Load training data

# %%
# Load model data
data = dataObject("""
SELECT * EXCEPT(load_rank)
FROM (
  SELECT
  RANK() OVER (PARTITION BY ticker_time ORDER BY etl_time) AS load_rank,
  * EXCEPT(
    conversionType, conversionSymbol, open_close1,
    LAG1_open, LAG1_high, LAG1_low, LAG1_close,
    LAG2_open, LAG2_high, LAG2_low, LAG2_close,
    LAG3_open, LAG3_high, LAG3_low, LAG3_close,
    LAG4_open, LAG4_high, LAG4_low, LAG4_close,
    LAG5_open, LAG5_high, LAG5_low, LAG5_close,
    LAG6_open, LAG6_high, LAG6_low, LAG6_close,
    LAG7_open, LAG7_high, LAG7_low, LAG7_close,
    LAG8_open, LAG8_high, LAG8_low, LAG8_close,
    LAG9_open, LAG9_high, LAG9_low, LAG9_close,
    LAG10_open, LAG10_high, LAG10_low, LAG10_close,
    LAG11_open, LAG11_high, LAG11_low, LAG11_close,
    LAG12_open, LAG12_high, LAG12_low, LAG12_close,
    LAG13_open, LAG13_high, LAG13_low, LAG13_close,
    LAG14_open, LAG14_high, LAG14_low, LAG14_close,
    LAG15_open, LAG15_high, LAG15_low, LAG15_close,
    LAG16_open, LAG16_high, LAG16_low, LAG16_close,
    LAG17_open, LAG17_high, LAG17_low, LAG17_close,
    LAG18_open, LAG18_high, LAG18_low, LAG18_close,
    LAG19_open, LAG19_high, LAG19_low, LAG19_close,
    LAG20_open, LAG20_high, LAG20_low, LAG20_close,
    LAG21_open, LAG21_high, LAG21_low, LAG21_close,
    LAG22_open, LAG22_high, LAG22_low, LAG22_close,
    LAG23_open, LAG23_high, LAG23_low, LAG23_close,
    LAG24_open, LAG24_high, LAG24_low, LAG24_close,
    
    LAG1_volume_base, LAG2_volume_base, LAG3_volume_base,
    LAG4_volume_base, LAG5_volume_base, LAG6_volume_base,
    LAG7_volume_base, LAG8_volume_base, LAG9_volume_base,
    LAG10_volume_base, LAG11_volume_base, LAG12_volume_base,
    LAG13_volume_base, LAG14_volume_base, LAG15_volume_base,
    LAG16_volume_base, LAG17_volume_base, LAG18_volume_base,
    LAG19_volume_base, LAG20_volume_base, LAG21_volume_base,
    LAG22_volume_base, LAG23_volume_base, LAG24_volume_base
    )
  FROM `algom-trading.train_features.features_BTC_USDT_hour_i04_*`
  WHERE 
    _table_suffix IN (
      '20170101',
      '20180101',
      '20190101')
    AND year BETWEEN 2017 AND 2019
    AND LAG24_close > 0
)
WHERE load_rank = 1
ORDER BY ticker_time
""")
# Out:
# RUNNING: Querying SQL script.
# Downloading: 100%|██████████| 20780/20780 [00:34<00:00, 601.34rows/s]
# SUCCESS: Loaded SQL query.

# %%
# Drop nan values
data.df = data.df.replace([np.inf, -np.inf], np.nan).dropna()
print(len(data.df))
data.df.head()
# Out:
# 20079
#    ticker_time_sec    close     high      low     open  volume_base  \
# 0       1503028800  4287.92  4292.39  4234.43  4292.39        50.69
# 1       1503032400  4313.56  4340.62  4250.04  4287.92        64.00
# 2       1503036000  4279.46  4316.98  4247.75  4313.56        63.95
# 3       1503039600  4300.25  4304.67  4270.48  4279.46        68.92
# 4       1503043200  4282.73  4320.71  4259.85  4300.25        73.83
#
#       volume partition_date                         etl_time  \
# 0  216069.15     2021-01-04 2021-01-04 13:32:27.262061+00:00
# 1  274857.30     2021-01-04 2021-01-04 13:32:27.262061+00:00
# 2  274013.68     2021-01-04 2021-01-04 13:32:27.262061+00:00
# 3  295447.38     2021-01-04 2021-01-04 13:32:27.262061+00:00
# 4  316938.59     2021-01-04 2021-01-04 13:32:27.262061+00:00
#
#                 ticker_time  ... volume_lag15 volume_lag16 volume_lag17  \
# 0 2017-08-18 04:00:00+00:00  ...     0.499514     0.788931     0.629151
# 1 2017-08-18 05:00:00+00:00  ...     0.212652     0.732668     1.022085
# 2 2017-08-18 06:00:00+00:00  ...    -0.058313     0.211870     0.731886
# 3 2017-08-18 07:00:00+00:00  ...     0.025720     0.016532     0.286715
# 4 2017-08-18 08:00:00+00:00  ...     0.215117     0.094538     0.085350
#
#    volume_lag18  volume_lag19  volume_lag20  volume_lag21  volume_lag22  \
# 0      0.750178      1.549893      3.977127      2.434399      1.947490
# 1      0.862306      0.983332      1.783048      4.210282      2.667553
# 2      1.021304      0.861524      0.982551      1.782266      4.209500
# 3      0.806731      1.096149      0.936369      1.057396      1.857111
# 4      0.355534      0.875550      1.164967      1.005188      1.126214
#
#    volume_lag23  volume_lag24
# 0      0.780284      0.130015
# 1      2.180644      1.013439
# 2      2.666772      2.179862
# 3      4.284345      2.741617
# 4      1.925930      4.353164
#
# [5 rows x 129 columns]

# %% [markdown]
# <br>
#
# ### Initialize modelRegression class

# %%
# Initialize model class
model = modelRegression(
    data, 
    outcome='ROR_n24',
    index_features=configs.INDEX_FEATURES, 
    omit_features=configs.OMIT_FEATURES
)
# Out:
# SUCCESS: Loaded dataObject.
# Initialized model. As a next step, run self.predict() or self.train().

# %%
# len(model.feature_list)
# list(model.feature_list)

# %%
# Specify regression parameters
from sklearn import ensemble
reg = ensemble.GradientBoostingRegressor(
    loss='ls', 
    learning_rate=0.1,
    n_estimators=500,
    subsample=.9,
    criterion='friedman_mse', 
    min_samples_split=3, 
    min_samples_leaf=3,
    min_weight_fraction_leaf=0.0,
    max_depth=20,
    min_impurity_decrease=0.0, 
    min_impurity_split=None, 
    init=None,
    random_state=None, 
    max_features=None, 
    alpha=0.9, 
    verbose=0,
    max_leaf_nodes=None, 
    warm_start=False, 
    validation_fraction=0.1, 
    n_iter_no_change=None, 
    tol=0.0001
)


# Train model
model.train(reg)
# Out:
# Training model on ROR_n24.
# Model metadata added to `self.metadata.metadata`
# Model metadata added to `self.metadata.parameters`
# Set feature_importance to `self.feature_importance.feature_importance`
# Fit model in 0:00:00.000017.
# Get model performance.
# Set evaluation to self.evaluations in 0:00:00.000017.
# Set R^2 to `self.rsquared`
# The following performance measures have been added:
#                 - self.mean_abs_error
#                 - self.mean_abs_outcome
#                 - self.mean_abs_pct_error
#                 - self.error_var
#
# Performance metrics added to `self.performance`
#
# MODEL PERFORMANCE SUMMARY
#         - Mean Absolute Error:	 0.03113
#         - Mean Absolute Outcome:	 0.03069
#         - Mean Absolute Percent Error:	 1.01457
#         - Error Variance:	 0.00204
#         - R-Squared:		 0.03328
#
# PLOT PREDICTIONS: Use the following commandsto view model performance.
#               `self.plot_predictions_by_date(start_date, end_date)`
#               `self.plot_predictions_histogram(start_date, end_date)`
#               `self.plot_errors_by_date(start_date, end_date)`
#               `self.plot_errors_histogram(start_date, end_date)`
#               `self.plot_predictions_scatterplot(start_date, end_date)`

# %%
# Model IDs
print('model_id: ' + model.model_id)
print('model_execution_id: ' + model.model_execution_id)
# Out:
# model_id: 29dcb976d865f6f9ad48f43e72756f776792a57e
# model_execution_id: a9ebc52ed563c252026560e17b45179422a0a779

# %%
# Save model (optional)
model.save()
# Out:
# Dumped model to:
# 	/home/jovyan/algomosaic/data/models/20210105_GradientBoostingRegressor_29dcb976d865f6f9ad48f43e72756f776792a57e.pickle
# Uploaded pickle to Google Storage:
# 	https://storage.googleapis.com/algom-trading-sto/models/20210105_GradientBoostingRegressor_29dcb976d865f6f9ad48f43e72756f776792a57e.pickle
# SUCCESS: Loaded DataFrame.
# 1it [00:05,  5.81s/it]
# Uploaded storage metadata to Google BigQuery:
# 	storage.model_storage_YYYYMMDD
# Saved model to Google Storage:
# 	models/20210105_GradientBoostingRegressor_29dcb976d865f6f9ad48f43e72756f776792a57e.pickle

# %% [markdown]
# <br>
#
# ## View performance
#
# + Trending predictions vs outcomes
# + Histogram of predictions vs outcomes

# %%
start_date='2019-04-01'
end_date='2019-05-01'
# %matplotlib inline
model_plot = modelPlots(model)

# %%
model_plot.plot_predictions_by_date(start_date, end_date)
# Out:
# PLOT: Predictions by Date
#         `self.plot_predictions_by_date(start_date, end_date)`

# %%
model_plot.plot_errors_by_date(start_date, end_date)
# Out:
# PLOT: Prediction Errors by Date`

# %%
model_plot.plot_predictions_histogram(start_date, end_date)
# Out:
# PLOT: Predictions Histogram

# %%
model_plot.plot_errors_histogram(start_date, end_date)
# Out:
# PLOT: Predictions Histogram

# %%
model_plot.plot_predictions_scatterplot(start_date, end_date)
# Out:
# PLOT: Predictions by Date

# %% [markdown]
# <br>
#
# ### Most important features

# %%
features = model.feature_importance.feature_importance
features[0:30]
# Out:
#                           model_execution_id  \
# 0   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 1   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 2   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 3   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 4   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 5   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 6   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 7   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 8   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 9   a7b8654031e746f8a48728dcaede91842a1b9ecf
# 10  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 11  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 12  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 13  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 14  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 15  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 16  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 17  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 18  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 19  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 20  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 21  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 22  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 23  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 24  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 25  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 26  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 27  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 28  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 29  a7b8654031e746f8a48728dcaede91842a1b9ecf
#
#                                      data_id outcome_variable      variable  \
# 0   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   day_of_week
# 1   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   hour_of_day
# 2   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close1
# 3   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low24
# 4   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high24
# 5   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low1
# 6   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_high1
# 7   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low2
# 8   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low5
# 9   6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low23
# 10  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high23
# 11  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low21
# 12  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low3
# 13  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low19
# 14  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high22
# 15  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high20
# 16  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low22
# 17  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low9
# 18  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low4
# 19  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close24
# 20  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low20
# 21  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low10
# 22  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low6
# 23  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low11
# 24  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low18
# 25  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close2
# 26  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high19
# 27  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close21
# 28  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high13
# 29  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24     open_low7
#
#     importance  rank  pct_rank
# 0      0.08262   1.0  1.000000
# 1      0.03831   2.0  0.986486
# 2      0.03350   3.0  0.972973
# 3      0.02898   4.0  0.959459
# 4      0.02817   5.0  0.945946
# 5      0.02579   6.0  0.932432
# 6      0.01914   7.0  0.918919
# 7      0.01906   8.0  0.905405
# 8      0.01823   9.0  0.891892
# 9      0.01807  10.0  0.878378
# 10     0.01669  11.0  0.864865
# 11     0.01615  12.0  0.851351
# 12     0.01576  13.0  0.837838
# 13     0.01571  14.0  0.824324
# 14     0.01560  15.0  0.810811
# 15     0.01520  16.0  0.797297
# 16     0.01456  17.0  0.783784
# 17     0.01454  18.0  0.770270
# 18     0.01438  19.0  0.756757
# 19     0.01425  20.0  0.743243
# 20     0.01415  21.0  0.729730
# 21     0.01367  22.0  0.716216
# 22     0.01360  23.0  0.702703
# 23     0.01318  24.0  0.689189
# 24     0.01307  25.0  0.675676
# 25     0.01303  26.0  0.662162
# 26     0.01259  27.0  0.648649
# 27     0.01251  28.0  0.635135
# 28     0.01218  29.0  0.621622
# 29     0.01211  30.0  0.608108

# %% [markdown]
# <br>
#
# ### Least import features

# %%
features[len(features)-20:len(features)]
# Out:
#                           model_execution_id  \
# 54  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 55  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 56  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 57  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 58  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 59  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 60  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 61  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 62  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 63  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 64  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 65  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 66  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 67  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 68  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 69  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 70  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 71  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 72  a7b8654031e746f8a48728dcaede91842a1b9ecf
# 73  a7b8654031e746f8a48728dcaede91842a1b9ecf
#
#                                      data_id outcome_variable      variable  \
# 54  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low12
# 55  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high10
# 56  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_high4
# 57  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close9
# 58  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close17
# 59  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close20
# 60  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close13
# 61  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close11
# 62  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close6
# 63  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_high7
# 64  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close15
# 65  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close14
# 66  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24    open_low13
# 67  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close12
# 68  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close4
# 69  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close7
# 70  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close16
# 71  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_close8
# 72  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24  open_close10
# 73  6eef6648406c333a4035cd5e60d0bf2ecf2606d7          ROR_n24   open_high11
#
#     importance  rank  pct_rank
# 54     0.00903  55.0  0.270270
# 55     0.00892  56.0  0.256757
# 56     0.00849  57.0  0.243243
# 57     0.00847  58.0  0.229730
# 58     0.00826  59.0  0.216216
# 59     0.00808  60.0  0.202703
# 60     0.00804  61.0  0.189189
# 61     0.00796  62.0  0.175676
# 62     0.00789  63.0  0.162162
# 63     0.00787  64.0  0.148649
# 64     0.00740  65.0  0.135135
# 65     0.00732  66.0  0.121622
# 66     0.00710  67.0  0.108108
# 67     0.00708  68.0  0.094595
# 68     0.00707  69.5  0.074324
# 69     0.00707  69.5  0.074324
# 70     0.00691  71.0  0.054054
# 71     0.00689  72.0  0.040541
# 72     0.00676  73.0  0.027027
# 73     0.00632  74.0  0.013514

# %% [markdown]
# <br>
#
# ### View trending features

# %%
start_date = '2016-01-01'
end_date = '2017-01-01'
# %matplotlib inline 

# from data_mgmt import data_mgmt as dm

model_plot.plot_features(
    df = model.df, 
    x = 'ticker_time', 
    y = 'ROR_n10',
    start_date=start_date, 
    end_date=end_date
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-aebe06cff970> in <module>
#       5 # from data_mgmt import data_mgmt as dm
#       6
# ----> 7 model_plot.plot_features(
#       8     df = model.df,
#       9     x = 'ticker_time',
#
# AttributeError: 'modelPlots' object has no attribute 'plot_features'

# %%
model_plot.plot_features(df = model.df, x = 'ticker_time', y = 'ATR_7',
    start_date=start_date, end_date=end_date, chart_type = 'line')

model_plot.plot_features(df = model.df, x = 'ticker_time', y = 'EMA_20',
    start_date=start_date, end_date=end_date, chart_type='line')
